# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
n = np.linspace(0, 10, 100)

# %%
plt.plot(n, np.sin(n), 'b--')
plt.plot(n, np.cos(n), 'r--')
plt.show()

# %%
import seaborn as sns

# %%
plt.plot(n, np.cos(n), 'b--')
plt.show()
